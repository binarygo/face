# %%
# %matplotlib inline

import time
import numpy as np
import tensorflow as tf

import alexnet_model
import alexnet_train
from caffe_classes import class_names

from copy import deepcopy
from matplotlib import pyplot as plt
from matplotlib import patches as patches
from scipy.misc import imread

reload(alexnet_model);
reload(alexnet_train);

# %%
bvlc_init_data = alexnet_train.read_bvlc_init_data()

# %%
def read_image(file_name):
    oim = imread(file_name)[:,:,:3]
    plt.imshow(oim)
    im = oim.astype(np.float32)
    im = im - np.mean(im)
    return im

# %%
im1 = read_image("poodle.png")

# %%
im2 = read_image("laska.png")

# %%
probs = alexnet_train.eval([im1, im2], bvlc_init_data)
# Out:
# conv1.shape = (?, 57, 57, 96)
# lrn1.shape = (?, 57, 57, 96)
# maxpool1.shape = (?, 28, 28, 96)
# conv2.shape = (?, 28, 28, 256)
# lrn2.shape = (?, 28, 28, 256)
# maxpool2.shape = (?, 13, 13, 256)
# conv3.shape = (?, 13, 13, 384)
# conv4.shape = (?, 13, 13, 384)
# conv5.shape = (?, 13, 13, 256)
# maxpool5.shape = (?, 6, 6, 256)
# fc6.shape = (?, 1, 1, 4096)
# fc7.shape = (?, 1, 1, 4096)
# fc8.shape = (?, 1, 1, 1000)
# probs.shape = (?, 1, 1, 1000)
# Take 0.637169 seconds.

# %%
alexnet_train.top_n_classes(probs[0,:], 5)
# Out:
# [('miniature poodle', 0.38945776),
#  ('toy poodle', 0.22309163),
#  ('Bedlington terrier', 0.17304777),
#  ('standard poodle', 0.149645),
#  ('komondor', 0.025833651)]

# %%
alexnet_train.top_n_classes(probs[1,:], 5)
# Out:
# [('weasel', 0.33129436),
#  ('polecat, fitch, foulmart, foumart, Mustela putorius', 0.28026101),
#  ('black-footed ferret, ferret, Mustela nigripes', 0.21049817),
#  ('mink', 0.081419162),
#  ('Arctic fox, white fox, Alopex lagopus', 0.026754923)]
